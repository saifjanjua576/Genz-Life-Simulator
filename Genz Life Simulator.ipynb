# %%
# 🌈 GenZ Life Simulator 🎮
# -------------------------------------------------
# 🧩 PROFILE SETUP
# -------------------------------------------------
def create_profile():
    print("✨ Welcome to the GenZ Life Simulator ✨")
    print("Let's set up your profile, bestie 😎\n")
    name = input("👉 What's your name? ")
    age = int(input("🎂 How old are you? "))

    # ⭐ NEW CHANGE (Commit 2)
    fav_app = input("📱 What's your favorite social media app? ")

    user = {"name": name, "age": age, "favorite_app": fav_app}
    print(f"\n💖 Welcome {name}! You're officially part of the GenZ Life Simulator 💅\n")
    return user

# -------------------------------------------------
# 💬 CHATBOT FUNCTIONS
# -------------------------------------------------
responses = {
    "hi": "Hey bestie! 💅",
    "hello": "Hiii 👋",
    "how are you": "I’m vibing, wbu? 😌",
    "bye": "Aww, see you soon 👋😭"
}

def GreetUser(user):
    print("━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
    print(f"Yo {user['name']} 👋! I'm your GenZ AI Bestie 🤖💖")
    print("Type anything to chat — or say 'play' to start the simulator 🎮")
    print("━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\n")

def GetResponse(user_input):
    user_input = user_input.lower()
    if user_input in responses:
        return responses[user_input]
    elif "play" in user_input or "game" in user_input:
        return "Ooo want to play GenZ Life Simulator with me? (yes/no)"
    else:
        return "Hmm… idk what to say 😶🌫️"

def EndChat():
    print("\n━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
    print("Okay bestie 😭 cya later 💖✨ Stay slaying 💅")
    print("━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\n")

# -------------------------------------------------
# ⚙️ GAME FUNCTIONS
# -------------------------------------------------
energy = 100
points = 0
mood = "😊"

def ShowStatus():
    print("━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
    print(f"📊 STATUS → Energy: {energy} ⚡ | Points: {points} 🏆 | Mood: {mood}")
    print("━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")

def UpdateStats(activity):
    global energy, points, mood
    if activity == "study":
        energy -= 20
        points += 10
        mood = "😐 Focused but tired"
        print("\n📚 You studied hard! Knowledge +10, Energy -20.")
    elif activity == "eat":
        energy += 15
        if energy > 100: energy = 100
        mood = "😋 Full and happy"
        print("\n🍔 You had some good food! Energy +15.")
    elif activity == "play":
        energy -= 10
        points += 5
        mood = "🤪 Having fun!"
        print("\n🎮 Gaming time! Points +5, Energy -10.")
    elif activity == "sleep":
        energy = 100
        mood = "😴 Well rested"
        print("\n💤 You took a power nap! Energy restored.")
    else:
        print("Bruh that’s not even an option 😭")
    ShowStatus()

def EndGame(user):
    print("\n━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
    print("🎮 GAME OVER 🎮")
    print(f"{user['name']}, you ended with {points} points and {energy} energy!")
    print("Hope you had fun, bestie 😎✨")
    print("\n💖 Thanks for playing the GenZ Life Simulator! See you again ✨")
    print("━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\n")

# -------------------------------------------------
# 🕒 DAILY ROUTINE FUNCTION
# -------------------------------------------------
def daily_routine():
    print("\n🕒 Your Daily GenZ Routine:")
    print("1. Wake up and check phone 😂")
    print("2. Scroll social media for 2 hours")
    print("3. Eat brunch 🍟")
    print("4. Play games 🎮")
    print("5. Sleep late 😴")

# -------------------------------------------------
# 🌈 UNIQUE FEATURE: DAILY VIBE CHECK 🎧
# -------------------------------------------------
import random

def DailyVibeCheck():
    vibes = [
        "🔥 Energetic!",
        "😴 Sleepy mode",
        "💀 Dead inside",
        "😂 Feeling goofy",
        "🧘 Calm and chill",
        "💃 Slaying mood"
    ]
    today_vibe = random.choice(vibes)
    print("━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
    print(f"🌈 Daily Vibe Check: You’re feeling {today_vibe}")
    print("━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
    return today_vibe

# -------------------------------------------------
# 🚀 MAIN PROGRAM LOOP
# -------------------------------------------------
user = create_profile()
GreetUser(user)

# Show daily routine once at the start
daily_routine()

while True:
    user_input = input("🫵 You: ")
    reply = GetResponse(user_input)
    print("🤖 AI Bestie:", reply)

    if "play genz life simulator" in reply.lower() or "want to play" in reply.lower():
        choice = input("\n👉 Your answer (yes/no): ").lower()
        if choice == "yes":
            print("\n✨ Starting GenZ Life Simulator ✨")
            mood = DailyVibeCheck()  # Unique feature
            while True:
                print("\n⚡ Choose an activity: study | eat | play | sleep | quit")
                activity = input("👉 What do you want to do? ").lower()
                if activity == "quit":
                    EndGame(user)
                    break
                else:
                    UpdateStats(activity)
        else:
            print("Aight, we’ll chill here instead 😎")

    elif user_input.lower() == "bye":
        EndChat()
        break
# Out:
# ✨ Welcome to the GenZ Life Simulator ✨
# Let's set up your profile, bestie 😎
#
# 👉 What's your name? saif
# 🎂 How old are you? 20
# 📱 What's your favorite social media app? instagram
#
# 💖 Welcome saif! You're officially part of the GenZ Life Simulator 💅
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Yo saif 👋! I'm your GenZ AI Bestie 🤖💖
# Type anything to chat — or say 'play' to start the simulator 🎮
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# 🕒 Your Daily GenZ Routine:
# 1. Wake up and check phone 😂
# 2. Scroll social media for 2 hours
# 3. Eat brunch 🍟
# 4. Play games 🎮
# 5. Sleep late 😴
# 🫵 You: eat brunch
# 🤖 AI Bestie: Hmm… idk what to say 😶🌫️
# 🫵 You: wake up and check phone
# 🤖 AI Bestie: Hmm… idk what to say 😶🌫️
# 🫵 You: sleep late
# 🤖 AI Bestie: Hmm… idk what to say 😶🌫️
# 🫵 You: play games
# 🤖 AI Bestie: Ooo want to play GenZ Life Simulator with me? (yes/no)
#
# 👉 Your answer (yes/no): yes
#
# ✨ Starting GenZ Life Simulator ✨
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ...
